# %% [markdown]
# <a href="https://www.kaggle.com/code/likithadasarathan/question-3?scriptVersionId=131613721" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#1
import pandas as pd

l = [10,20,30,40,50]
#list to series
m=pd.Series(l)
print(m)

d1 = {"a":10,"b":20,"c":30,"d":40,"e":50}
#dictionary to series
d2=pd.Series(d1)
print(d2)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
#2
import pandas as pd
import numpy as np
ser_1=pd.Series([1,2,3,4,5],index=["India","Srilanka","Bangladesh","Russia","England"],name="SERIES 1")
print(ser_1)
ser_2=pd.Series([6,7,8,9,10],index=["India","Srilanka","Bangladesh","Russia","England"],name="SERIES 2")
print(ser_2)
ser_3=ser_1+ser_2
print(ser_3)
# Out:
# India         1
# Srilanka      2
# Bangladesh    3
# Russia        4
# England       5
# Name: SERIES 1, dtype: int64
# India          6
# Srilanka       7
# Bangladesh     8
# Russia         9
# England       10
# Name: SERIES 2, dtype: int64
# India          7
# Srilanka       9
# Bangladesh    11
# Russia        13
# England       15
# dtype: int64

# %%
#3
import pandas as pd
import numpy as np
data=np.random.rand(5,4)
df=pd.DataFrame(data,index=['A','B','C','D','E'],columns=['W','X','Y','Z'])
print(df)
# Out:
#           W         X         Y         Z
# A  0.883377  0.340343  0.361213  0.701429
# B  0.860306  0.277968  0.817560  0.462904
# C  0.847531  0.382118  0.529873  0.161783
# D  0.861393  0.181950  0.946006  0.690210
# E  0.083868  0.660813  0.656432  0.092588

# %%
#4
import pandas as pd
import numpy as np
data=np.random.rand(5,4)
df=pd.DataFrame(data,index=['A','B','C','D','E'],columns=['W','X','Y','Z'])
df.to_excel("/kaggle/working/hello.xlsx")

# %%
#5
import pandas as pd
import numpy as np
data=np.random.rand(5,4)
df=pd.DataFrame(data,index=['A','B','C','D','E'],columns=['W','X','Y','Z'])
print("Row =",df.iloc[2])
print("Column =",df.iloc[:,2])
print("Row and column =",df.iloc[1,1])
print("A row =",df.loc['A'])
print(df.iloc[0])
print("Row and column =",df.loc[['A','B'],['W','Z']])
df=df.drop('A')
# Out:
# Row = W    0.445704
# X    0.187867
# Y    0.583344
# Z    0.110373
# Name: C, dtype: float64
# Column = A    0.643251
# B    0.995556
# C    0.583344
# D    0.485561
# E    0.844117
# Name: Y, dtype: float64
# Row and column = 0.6236415139645147
# A row = W    0.893258
# X    0.881412
# Y    0.643251
# Z    0.928934
# Name: A, dtype: float64
# W    0.893258
# X    0.881412
# Y    0.643251
# Z    0.928934
# Name: A, dtype: float64
# Row and column =           W         Z
# A  0.893258  0.928934
# B  0.475777  0.817803
