# %% [markdown]
# <a href="https://www.kaggle.com/code/likithadasarathan/question-2?scriptVersionId=131613498" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#1
import numpy as np
from array import *

arr = [3,4,-2,5,1,-5,25,-6,9]
array_1=[4,16,64,25]
array_0=np.array(array_1)
print(np.sort(arr))
array_5=array_0.reshape(2,2)
print(array_5)
# Out:
# [-6 -5 -2  1  3  4  5  9 25]
# [[ 4 16]
#  [64 25]]

# %%
#2
import numpy as np
arr = [3,4,-2,5,1,-5,25,-6,9]
print("Absolute =",np.abs(arr))
array_6=np.abs(arr)
print("Sqrt =",np.sqrt(array_6))
print("Sqrt =",np.sqrt(arr))
print("Exp =",np.exp(arr))
print("Square =",np.square(arr))
print("SIn =",np.sin(arr))
print("Cos =",np.cos(arr))
print("Tan =",np.tan(arr))
# Out:
# Absolute = [ 3  4  2  5  1  5 25  6  9]
# Sqrt = [1.73205081 2.         1.41421356 2.23606798 1.         2.23606798
#  5.         2.44948974 3.        ]
# Sqrt = [1.73205081 2.                nan 2.23606798 1.                nan
#  5.                nan 3.        ]
# Exp = [2.00855369e+01 5.45981500e+01 1.35335283e-01 1.48413159e+02
#  2.71828183e+00 6.73794700e-03 7.20048993e+10 2.47875218e-03
#  8.10308393e+03]
# Square = [  9  16   4  25   1  25 625  36  81]
# SIn = [ 0.14112001 -0.7568025  -0.90929743 -0.95892427  0.84147098  0.95892427
#  -0.13235175  0.2794155   0.41211849]
# Cos = [-0.9899925  -0.65364362 -0.41614684  0.28366219  0.54030231  0.28366219
#   0.99120281  0.96017029 -0.91113026]
# Tan = [-0.14254654  1.15782128  2.18503986 -3.38051501  1.55740772  3.38051501
#  -0.13352641  0.29100619 -0.45231566]
# /tmp/ipykernel_20/2221343881.py:7: RuntimeWarning: invalid value encountered in sqrt
#   print("Sqrt =",np.sqrt(arr))

# %%
import numpy as np
weight=[75,68,82,87,69]
height=[170,165,175,180,168]
#3
print("Mean of weight = ",np.mean(weight))
#4
print("Sum of height = ",np.sum(height))
#5
print("Standard deviation of weight = ",np.std(weight))
#6
print("Standard deviation of height = ",np.std(height))
# Out:
# Mean of weight =  76.2
# Sum of height =  858
# Standard deviation of weight =  7.35934779718964
# Standard deviation of height =  5.314132102234569
